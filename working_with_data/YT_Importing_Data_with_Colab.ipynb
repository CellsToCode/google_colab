# %% [markdown]
# <a href="https://colab.research.google.com/github/CellsToCode/google_colab/blob/main/working_with_data/YT_Importing_Data_with_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing and Exporting data with Colab!
# ---

# %% [markdown]
# Notebook used in tutorial on [www.cellstocode.com](https://cellstocode.com/how-to-import-data-into-google-colab/) and [Youtube](https://www.youtube.com/channel/UCWsV0g7vAE4EJJwPc30VJfA) to help spreadsheet users learn how to use Python and other coding tools!

# %% [markdown]
# ## **Excel:**
#
# *   Data is imported by opening CSV, XLSX, or other text file
# *   Other methods include copy+paste, loading from a database, web

# %% [markdown]
# ## **Python:**
#
#
#
# *   Can load from same sources as Excel and more
# *   3 main ways to import data
#   1. Upload to session storage
#   2. Load from your Google Drive
#   3. Directly from URL
#
# <br>
#
# **Loading an Excel file:**
#
#     data = pd.read_excel('filename.xlsx', sheet_name='sheet_name_in_workbook')
#
# <br>
#
# **Loading a CSV file**
#
#     data = pd.read_csv('filename.csv')
#
# <br>
#
# **Exporting data**
#
#     data.to_csv('exported_filename.csv')
#     data.to_excel('exported_filename.xlsx')
#
# <br>

# %% [markdown]
# ## Load required packages
# ---

# %%
# Import required packages

# %% [markdown]
# <br><br>
#
# ## 1) Import data from session storage (temporary, applies to this notebook only)
# ---

# %%
# Load "failed_banks.xlsx", save as bank_detail
bank_detail =

# %% [markdown]
# <br>

# %%
# Inspect bank_detail
bank_detail

# %% [markdown]
# <br>

# %% [markdown]
# <br><br>
#
# ## 2) Import data from Google Drive
# ---

# %% [markdown]
# ##### Option 1: In Left Navigation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### Option 2: Using google.colab package

# %%
# Mount Google Drive via code

# %% [markdown]
# <br>

# %%
# Read "failed_banks.xlsx" from Google Drive, save as 'bank_detail_drive'
bank_detail_drive =

# %% [markdown]
# <br>

# %%
# Inspect bank_detail_drive
bank_detail_drive

# %% [markdown]
# <br>

# %% [markdown]
# <br><br>
#
# ## 3) Import data from URL
# ---

# %% [markdown]
# ### **[GitHub Datasets](https://github.com/CellsToCode/Datasets)**

# %%
# URL for "failed_bank.xlsx"
failed_bank_path = ''

# %% [markdown]
# <br>

# %%
# Feed URL into appropriate read function, call 'bank_detail_web'
bank_detail_web = pd.read_excel(failed_bank_path, sheet_name='detail')

# %% [markdown]
# <br>

# %%
# Inspect data
bank_detail_web

# %% [markdown]
# <br>
